# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people1.jpg')
display (image.shape)
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(image)
plt.show()

# %%
print(image)
# Out:
# [[[ 91 103 107]
#   [102 114 118]
#   [ 94 106 110]
#   ...
#   [187 192 193]
#   [186 191 192]
#   [185 190 191]]
#
#  [[ 93 105 109]
#   [ 97 109 113]
#   [ 95 110 113]
#   ...
#   [187 192 193]
#   [186 191 192]
#   [185 190 191]]
#
#  [[ 98 110 114]
#   [ 98 110 114]
#   [102 117 120]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]
#
#  ...
#
#  [[ 48  43  40]
#   [ 46  41  38]
#   [ 44  39  36]
#   ...
#   [251 248 244]
#   [252 247 244]
#   [251 246 243]]
#
#  [[ 55  49  44]
#   [ 53  47  42]
#   [ 49  42  39]
#   ...
#   [252 247 244]
#   [252 247 244]
#   [252 247 244]]
#
#  [[ 56  50  45]
#   [ 54  48  43]
#   [ 50  44  39]
#   ...
#   [253 248 245]
#   [253 248 245]
#   [253 248 245]]]

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
cv2.imshow('', image)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
image = cv2.resize(image, (800, 600))


print (image.shape)
# Out:
# (600, 800, 3)

# %%
cv2.imshow('',image)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
display (image_gray.shape)
# Out:
# (1280, 1920)

# %%
face_detector = cv2.CascadeClassifier('/Users/akshhat/Documents/Face-Detection-System/Cascades/haarcascade_frontalface_default.xml')
display (face_detector)
# Out:
# < cv2.CascadeClassifier 0x11de1c050>

# %%
detections = face_detector.detectMultiScale(image_gray)
display (detections)
# Out:
# array([[1639,  159,  141,  141],
#        [ 284,  263,  113,  113],
#        [1148,  261,  129,  129],
#        [ 928,  488,  172,  172],
#        [ 229,  509,  142,  142],
#        [ 103,  784,   56,   56],
#        [  44,  919,   30,   30]], dtype=int32)

# %%
display (len(detections))
# Out:
# 7

# %%
x=390  # X - Co ordinates 
y=323  # Y- Co ordinates 
w=56   # Face Width
h=56   # Face Height

# %%
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 1)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
x=115  # X - Co ordinates 
y=124  # Y- Co ordinates 
w=52   # Face Width
h=52   # Face Height

# %%
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
x=475  # X - Co ordinates 
y=123  # Y- Co ordinates 
w=59   # Face Width
h=59  # Face Height 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people1.jpg')
display (image.shape)
image = cv2.resize(image, (800, 600)) # Resize image
display (image.shape) 
detections = face_detector.detectMultiScale(image)
display (detections)
# Out:
# (1280, 1920, 3)
# (600, 800, 3)
# array([[677,  72,  68,  68],
#        [115, 124,  52,  52],
#        [475, 123,  59,  59],
#        [387, 233,  73,  73],
#        [ 92, 239,  67,  67],
#        [390, 323,  56,  56]], dtype=int32)

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people1.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[678,  74,  65,  65],
#        [113, 123,  56,  56],
#        [476, 123,  59,  59],
#        [385, 232,  75,  75],
#        [ 90, 238,  69,  69]], dtype=int32)

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people1.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people1.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[1630,  157,  146,  146],
#        [ 284,  263,  113,  113],
#        [1150,  261,  128,  128],
#        [ 895,  397,  218,  218],
#        [ 929,  490,  172,  172],
#        [1700,  478,   54,   54],
#        [ 229,  507,  145,  145],
#        [ 103,  786,   55,   55],
#        [  44,  920,   26,   26],
#        [ 365,  841,  102,  102]], dtype=int32)
# 146 146
# 113 113
# 128 128
# 218 218
# 172 172
# 54 54
# 145 145
# 55 55
# 26 26
# 102 102

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people1.jpg')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,minNeighbors=7)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[1634,  154,  148,  148],
#        [ 282,  263,  115,  115],
#        [1148,  262,  130,  130],
#        [ 927,  492,  173,  173],
#        [ 232,  511,  138,  138]], dtype=int32)
# 148 148
# 115 115
# 130 130
# 173 173
# 138 138

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people1.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,
                                            minNeighbors=7,minSize=(20,20), maxSize=(100,100))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[1150,  283,   76,   76]], dtype=int32)
# 76 76

# %%
eye_detector= cv2.CascadeClassifier('/Users/akshhat/Documents/Face-Detection-System/Cascades/haarcascade_eye.xml')
display (eye_detector)
# Out:
# < cv2.CascadeClassifier 0x11de1ed50>

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people1.jpg')
display (image.shape)

image = cv2.resize(image, (1600,1000)) # Resize image
print(image.shape)
face_detections = face_detector.detectMultiScale(image, scaleFactor = 1.3, minSize = (30,30))
for (x, y, w, h) in face_detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)

eye_detections = eye_detector.detectMultiScale(image, scaleFactor = 1.1, minNeighbors=10, maxSize=(60,60))

for (x, y, w, h) in eye_detections:
  print(w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,0,255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (1280, 1920, 3)
# (1000, 1600, 3)
# 34 34
# 28 28
# 23 23
# 23 23
# 28 28
# 33 33
# 31 31
# 25 25
# 22 22

# %%
car_detector = cv2.CascadeClassifier('/Users/akshhat/Documents/Face-Detection-System/Cascades/cars.xml')

display (car_detector)
# Out:
# < cv2.CascadeClassifier 0x11de1edf0>

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/car.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (286, 468, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = car_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=8)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
clock_detector = cv2.CascadeClassifier('/Users/akshhat/Documents/Face-Detection-System/Cascades/clocks.xml')
display (clock_detector)
# Out:
# < cv2.CascadeClassifier 0x11de1e990>

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/clock.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (438, 450, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = clock_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=1)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
full_detector  = cv2.CascadeClassifier('/Users/akshhat/Documents/Face-Detection-System/Cascades/fullbody.xml')
display (full_detector)
# Out:
# < cv2.CascadeClassifier 0x11de1ea10>

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people3.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (294, 626, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = full_detector.detectMultiScale(image_gray, scaleFactor = 1.05, minNeighbors=5,    minSize = (50,50)) 
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people2.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
import dlib

face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 1) # 1 – is the scale factor

# %%
display (len(detections))
display (detections)
# Out:
# 14
# rectangles[[(429, 38) (465, 74)], [(665, 90) (701, 126)], [(717, 103) (760, 146)], [(909, 70) (952, 113)], [(828, 98) (871, 142)], [(605, 70) (641, 106)], [(777, 62) (813, 98)], [(485, 78) (521, 114)], [(386, 60) (429, 103)], [(170, 41) (213, 84)], [(93, 89) (136, 132)], [(237, 50) (280, 94)], [(323, 50) (367, 94)], [(544, 65) (588, 108)]]

# %%
print(detections[0])
print(detections[0].left())
print(detections[0].top())
print(detections[0].right())
print(detections[0].bottom())
cv2.rectangle(image, (detections[0].left(), detections[0].top()), (detections[0].right(), detections[0].bottom()), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# [(429, 38) (465, 74)]
# 429
# 38
# 465
# 74

# %%
for face in detections:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people2.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
cnn_detector = dlib.cnn_face_detection_model_v1('/Users/akshhat/Documents/Face-Detection-System/Weights/mmod_human_face_detector.dat')
display (cnn_detector)

# %%
detections = cnn_detector(image, 1)
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# 1.1440681219100952
# 1.1370497941970825
# 1.1278996467590332
# 1.1200230121612549
# 1.114937424659729
# 1.1131552457809448
# 1.097571849822998
# 1.094212532043457
# 1.0853140354156494
# 1.0801893472671509
# 1.0800762176513672
# 1.0784763097763062
# 1.066403865814209
# 1.0641791820526123

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people3.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
haarcascade_detector = cv2.CascadeClassifier('/Users/akshhat/Documents/Face-Detection-System/Cascades/haarcascade_frontalface_default.xml')
detections = haarcascade_detector.detectMultiScale(image_gray, scaleFactor = 1.001, minNeighbors=5, minSize = (5,5))
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people3.jpg')
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 4)
for face in detections:
    l, t, r, b = (face.left(), face.top(), face.right(), face.bottom())
    cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
cnn_detector = dlib.cnn_face_detection_model_v1('/Users/akshhat/Documents/Face-Detection-System/Weights/mmod_human_face_detector.dat')
display (cnn_detector)

# %%
image = cv2.imread('/Users/akshhat/Documents/Face-Detection-System/Data Set/people3.jpg')
detections = cnn_detector(image, 1)
display (detections)
# Out:
# mmod_rectangles[]

# %%
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
